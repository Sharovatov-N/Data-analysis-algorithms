# %% [markdown]
# ## Урок 1. Алгоритм линейной регрессии. Градиентный спуск

# %% [markdown]
# ### Реализовать оптимизацию методом градиентного спуска для $x^2\cdot(sin(0,5\cdot x)^2+1)$. Какие параметры шага и количества итераций оптимальны? При каких значениях шага оптимизиция не выходит из локальных минимумов?

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-50, 50, 5000)
def func1(_x): return (_x**2) * (np.sin(0.5*_x)**2 + 1)
def grad1(_x): return 2 * _x * (np.sin(0.5*_x)**2 + 1) + _x**2 * np.sin(0.5*_x) * np.cos(0.5*_x)

# %%
def calculate_grad(func, x0, delta=0.01): return (func(x0+delta)-func(x0))/delta
def calculate_grad2(func, x0, delta=0.01): return (func(x0+delta)-func(x0-delta))/(2*delta)

# %%
x0=np.random.uniform(-50, 50)
print('true grad', grad1(x0))
print('method1', calculate_grad(func1, x0))
print('method2', calculate_grad2(func1, x0))
# Out:
# true grad 9.580420289119733
# method1 9.609726066516266
# method2 9.580370549964101

# %%
plt.plot(x, func1(x))
plt.show()

# %%
x0=np.random.uniform(-50, 50)
alpha=0.1
for x in range(50):
    print(x0, func1(x0))
    x0-=alpha*grad1(x0)
# Out:
# -33.157707552550754 1742.6861846255333
# 31.52385709931874 996.6448185418908
# 19.848329155869884 484.30328389094865
# -1.593777351842526 3.839374154285848
# -0.9850090288747907 1.1871621057873085
# -0.7035390411603477 0.5537303076717515
# -0.5301160055543295 0.30030840330581154
# -0.4097121478880231 0.1748106338388995
# -0.3210353644551761 0.10569650786217455
# -0.25356201332416756 0.06532158938023122
# -0.2012324312100925 0.04090306079825558
# -0.16017518182768334 0.025820296070578588
# -0.12773051500137855 0.016381539532346556
# -0.10197644327349537 0.010426207375679359
# -0.08147524511418185 0.00664922595009541
# -0.06512615593257345 0.004245911999982394
# -0.052073316675032164 0.00271346812892521
# -0.04164453776721651 0.0017350193381448617
# -0.03330840950237472 0.001109757835034219
# -0.026643032712387063 0.0007099771568404478
# -0.021312535078865158 0.00045427572943043334
# -0.017049060051239708 0.0002906915704465731
# -0.013638752493203943 0.00018602421988481513
# -0.010910748298430846 0.00011904797129055009
# -0.008728468754297952 7.618761786854568e-05
# -0.0069827085052140084 4.875881240733046e-05
# -0.005586132757936311 3.120512262477741e-05
# -0.004468888774957257 1.997106659265259e-05
# -0.0035751020951851125 1.2781395831712333e-05
# -0.0028600771066904897 8.18005778447156e-06
# -0.0022880593457999684 5.235222421770106e-06
# -0.0018304462787923673 3.3505363860628583e-06
# -0.0014643564097369785 2.1443408442857494e-06
# -0.0011714848137819092 1.372377139776011e-06
# -0.0009371876902537124 8.783209596249166e-07
# -0.0007497500698878379 5.6212524629299e-07
# -0.0005998000137649349 3.5976008886923965e-07
# -0.0004798399894335402 2.302464287129327e-07
# -0.00038387198049868874 1.4735770284055835e-07
# -0.00030709757874230196 9.430892509292758e-08
# -0.0002456780600976374 6.035771012410161e-08
# -0.00019654244659525344 3.862893368669667e-08
# -0.00015723395651698026 2.4722517234784355e-08
# -0.0001257871648248623 1.5822410897264244e-08
# -0.00010062973166086422 1.0126342919773246e-08
# -8.050378522679026e-05 6.480859446341558e-09
# -6.440302812925884e-05 4.147750036519062e-09
# -5.152242247669431e-05 2.654560019628647e-09
# -4.121793796767851e-05 1.6989184110289747e-09
# -3.297435036714022e-05 1.08730778243048e-09
